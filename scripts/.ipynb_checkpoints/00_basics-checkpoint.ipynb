# %% [markdown]
# # Our first notebook
#
# Here we are learning Python Variables and sone useful methods

# %% [markdown]
# ## Variables

# %%
mycal =2 + 2
mycal
# Out:
# 4

# %%
mystr='Hello'

# %%
mystr[1]
# Out:
# 'e'

# %%
mystr[2:]
# Out:
# 'llo'

# %%
print(mystr)
# Out:
# Hello

# %%
mydiv = 37.0/3.0

# %%
mydiv
# Out:
# 12.333333333333334

# %% [markdown]
# ## Types

# %%
type(mycal)
# Out:
# int

# %%
type(mydiv)
# Out:
# float

# %%
type(mystr)
# Out:
# str

# %%
help() # to close the help press Ctrl+C and then run Ctrl+Enter
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %% [markdown]
# # Libraries

# %%
import pandas # library for data manipulation

# %%
# %who # to list your variables
# Out:
# No variables match your requested type.

# %%
print(locals()) # same idea than %who
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'pandas.', 'import pandas # library for data manipulation', "get_ipython().run_line_magic('who', '# to list your variables')", 'print(locals()) # same idea than %who', 'import matplotlib', 'mycal =2 + 2\nmycal', "mystr='Hello'", 'mystr[1]', 'mystr[2:]', 'print(mystr)', 'mydiv = 37.0/3.0', 'mydiv', 'type(mycal)', 'type(mydiv)', 'type(mystr)', 'import pandas # library for data manipulation', "get_ipython().run_line_magic('who', '# to list your variables')", 'print(locals()) # same idea than %who'], '_oh': {6: 4, 8: 'e', 9: 'llo', 12: 12.333333333333334, 13: <class 'int'>, 14: <class 'float'>, 15: <class 'str'>}, '_dh': ['/home/emfro/Desktop/ComputingSkills/python-novice-gapminder-data/2018_10_24_SC/python-novice/scripts'
# ...

# %%
import matplotlib

# %%
anz = pandas.read_csv('../data/gapminder_gdp_oceania.csv') #variable anz with this data oceania inside

# %%
anz
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
anz = pandas.read_csv('../data/gapminder_gdp_oceania.csv', index_col = 'country')

# %%
anz
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
africa = pandas.read_csv('../data/gapminder_gdp_africa.csv', index_col = 'country')

# %%
europe = pandas.read_csv('../data/gapminder_gdp_europe.csv', index_col = 'country')

# %%
asia = pandas.read_csv('../data/gapminder_gdp_asia.csv', index_col = 'country')

# %%
asia
# Out:
#                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Afghanistan             779.445314      820.853030      853.100710
# Bahrain                9867.084765    11635.799450    12753.275140
# Bangladesh              684.244172      661.637458      686.341554
# Cambodia                368.469286      434.038336      496.913648
# China                   400.448611      575.987001      487.674018
# Hong Kong China        3054.421209     3629.076457     4692.648272
# India                   546.565749      590.061996      658.347151
# Indonesia               749.681655      858.900271      849.289770
# Iran                   3035.326002     3290.257643     4187.329802
# Iraq                   4129.766056     6229.333562     8341.737815
# Israel                 4086.522128     5385.278451     7105.630706
# Japan                  3216.956347     4317.694365     6576.649461
# Jordan                 1546.907807     1886.080591     2348.009158
# ...

# %%
europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
africa
# Out:
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                      2449.008185     3013.976023     2550.816880
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                        1062.752200      959.601080      949.499064
# Botswana                      851.241141      918.232535      983.653976
# Burkina Faso                  543.255241      617.183465      722.512021
# Burundi                       339.296459      379.564628      355.203227
# Cameroon                     1172.667655     1313.048099     1399.607441
# Central African Republic     1071.310713     1190.844328     1193.068753
# Chad                         1178.665927     1308.495577     1389.817618
# Comoros                      1102.990936     1211.148548     1406.648278
# Congo Dem. Rep.               780.542326      905.860230      896.314634
# Congo Rep.                   2125.621418     2315.056572     2464.783157
# ...

# %%
europe.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
europe.index # give the names in the index columns FIRST One
# Out:
# Index(['Albania', 'Austria', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria',
#        'Croatia', 'Czech Republic', 'Denmark', 'Finland', 'France', 'Germany',
#        'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Montenegro',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
#        'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom'],
#       dtype='object', name='country')

# %%
europe.axes # give the name of row and columns
# Out:
# [Index(['Albania', 'Austria', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria',
#         'Croatia', 'Czech Republic', 'Denmark', 'Finland', 'France', 'Germany',
#         'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Montenegro',
#         'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
#         'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#         'Turkey', 'United Kingdom'],
#        dtype='object', name='country'),
#  Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#         'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#         'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#        dtype='object')]

# %%
europe.dtypes #give the type of the numbers in the columns
# Out:
# gdpPercap_1952    float64
# gdpPercap_1957    float64
# gdpPercap_1962    float64
# gdpPercap_1967    float64
# gdpPercap_1972    float64
# gdpPercap_1977    float64
# gdpPercap_1982    float64
# gdpPercap_1987    float64
# gdpPercap_1992    float64
# gdpPercap_1997    float64
# gdpPercap_2002    float64
# gdpPercap_2007    float64
# dtype: object

# %%
europe.shape # give number of col and Row
# Out:
# (30, 12)

# %%
europe.size #give number of cells
# Out:
# 360

# %%
europe.values #give all values
# Out:
# array([[ 1601.056136 ,  1942.284244 ,  2312.888958 ,  2760.196931 ,
#          3313.422188 ,  3533.00391  ,  3630.880722 ,  3738.932735 ,
#          2497.437901 ,  3193.054604 ,  4604.211737 ,  5937.029526 ],
#        [ 6137.076492 ,  8842.59803  , 10750.72111  , 12834.6024   ,
#         16661.6256   , 19749.4223   , 21597.08362  , 23687.82607  ,
#         27042.01868  , 29095.92066  , 32417.60769  , 36126.4927   ],
#        [ 8343.105127 ,  9714.960623 , 10991.20676  , 13149.04119  ,
#         16672.14356  , 19117.97448  , 20979.84589  , 22525.56308  ,
#         25575.57069  , 27561.19663  , 30485.88375  , 33692.60508  ],
#        [  973.5331948,  1353.989176 ,  1709.683679 ,  2172.352423 ,
#          2860.16975  ,  3528.481305 ,  4126.613157 ,  4314.114757 ,
#          2546.781445 ,  4766.355904 ,  6018.975239 ,  7446.298803 ],
#        [ 2444.286648 ,  3008.670727 ,  4254.337839 ,  5577.0028   ,
#          6597.494398 ,  7612.240438 ,  8224.191647 ,  8239.854824 ,
# ...

# %%
europe.T #give the table
# Out:
# country             Albania       Austria       Belgium  \
# gdpPercap_1952  1601.056136   6137.076492   8343.105127
# gdpPercap_1957  1942.284244   8842.598030   9714.960623
# gdpPercap_1962  2312.888958  10750.721110  10991.206760
# gdpPercap_1967  2760.196931  12834.602400  13149.041190
# gdpPercap_1972  3313.422188  16661.625600  16672.143560
# gdpPercap_1977  3533.003910  19749.422300  19117.974480
# gdpPercap_1982  3630.880722  21597.083620  20979.845890
# gdpPercap_1987  3738.932735  23687.826070  22525.563080
# gdpPercap_1992  2497.437901  27042.018680  25575.570690
# gdpPercap_1997  3193.054604  29095.920660  27561.196630
# gdpPercap_2002  4604.211737  32417.607690  30485.883750
# gdpPercap_2007  5937.029526  36126.492700  33692.605080
#
# country         Bosnia and Herzegovina      Bulgaria       Croatia  \
# gdpPercap_1952              973.533195   2444.286648   3119.236520
# gdpPercap_1957             1353.989176   3008.670727   4338.231617
# ...

# %%
# %who
# Out:
# africa	 anz	 asia	 europe	 matplotlib	 mycal	 mydiv	 mystr	 pandas

# %%
del mycal #delete variable

# %%
print(africa.info()) #summary information of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, Algeria to Zimbabwe
# Data columns (total 12 columns):
# gdpPercap_1952    52 non-null float64
# gdpPercap_1957    52 non-null float64
# gdpPercap_1962    52 non-null float64
# gdpPercap_1967    52 non-null float64
# gdpPercap_1972    52 non-null float64
# gdpPercap_1977    52 non-null float64
# gdpPercap_1982    52 non-null float64
# gdpPercap_1987    52 non-null float64
# gdpPercap_1992    52 non-null float64
# gdpPercap_1997    52 non-null float64
# gdpPercap_2002    52 non-null float64
# gdpPercap_2007    52 non-null float64
# dtypes: float64(12)
# memory usage: 5.3+ KB
# None

# %%
africa.describe() #summary statistics per numeroc columns Useful for Boxplot
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      1252.572466     1385.236062     1598.078825     2050.363801
# std        982.952116     1134.508918     1461.839189     2847.717603
# min        298.846212      335.997115      355.203227      412.977514
# 25%        534.990554      606.954355      673.329046      779.815648
# 50%        987.025569     1024.022987     1133.783677     1210.376379
# 75%       1454.886645     1573.040442     1702.219247     1890.112274
# max       4725.295531     5487.104219     6757.030816    18772.751690
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      2339.615674     2585.938508     2481.592960     2282.668991
# std       3286.853884     4142.398707     3242.632753     2566.531947
# ...

# %%
africa.head(n=3) # show the first 5 lines of the DataFrame , if n=3 show the first 3 lines
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria     2449.008185     3013.976023     2550.816880     3246.991771
# Angola      3520.610273     3827.940465     4269.276742     5522.776375
# Benin       1062.752200      959.601080      949.499064     1035.831411
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria     4182.663766     4910.416756     5745.160213     5681.358539
# Angola      5473.288005     3008.647355     2756.953672     2430.208311
# Benin       1085.796879     1029.161251     1277.897616     1225.856010
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria     5023.216647     4797.295051     5288.040382     6223.367465
# Angola      2627.845685     2277.140884     2773.287312     4797.231267
# Benin       1191.207681     1232.975292     1372.877931     1441.284873

# %%
africa.tail() # the first bottom lines (5)
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Togo          859.808657      925.908320     1067.534810     1477.596760
# Tunisia      1468.475631     1395.232468     1660.303210     1932.360167
# Uganda        734.753484      774.371069      767.271740      908.918522
# Zambia       1147.388831     1311.956766     1452.725766     1777.077318
# Zimbabwe      406.884115      518.764268      527.272182      569.795071
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Togo         1649.660188     1532.776998     1344.577953     1202.201361
# Tunisia      2753.285994     3120.876811     3560.233174     3810.419296
# Uganda        950.735869      843.733137      682.266227      617.724406
# Zambia       1773.498265     1588.688299     1408.678565     1213.315116
# Zimbabwe      799.362176      685.587682      788.855041      706.157306
#
# ...

# %%
africa.gdpPercap_1952 # way to piking one of the column
# Out:
# country
# Algeria                     2449.008185
# Angola                      3520.610273
# Benin                       1062.752200
# Botswana                     851.241141
# Burkina Faso                 543.255241
# Burundi                      339.296459
# Cameroon                    1172.667655
# Central African Republic    1071.310713
# Chad                        1178.665927
# Comoros                     1102.990936
# Congo Dem. Rep.              780.542326
# Congo Rep.                  2125.621418
# Cote d'Ivoire               1388.594732
# Djibouti                    2669.529475
# Egypt                       1418.822445
# Equatorial Guinea            375.643123
# Eritrea                      328.940557
# Ethiopia                     362.146280
# Gabon                       4293.476475
# Gambia                       485.230659
# Ghana                        911.298937
# Guinea                       510.196492
# Guinea-Bissau                299.850319
# ...

# %%
africa.gdpPercap_1952.describe() #give data informations for the specific culumn
# Out:
# count      52.000000
# mean     1252.572466
# std       982.952116
# min       298.846212
# 25%       534.990554
# 50%       987.025569
# 75%      1454.886645
# max      4725.295531
# Name: gdpPercap_1952, dtype: float64

# %%
americas = pandas.read_csv('../data/gapminder_gdp_americas.csv', index_col = 'country') # Creat Dataframe americaS

# %%
americas.tail(n=3) #show the last three row
# Out:
#               continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# United States  Americas    13990.482080    14847.127120    16173.145860
# Uruguay        Americas     5716.766744     6150.772969     5603.357717
# Venezuela      Americas     7689.799761     9802.466526     8422.974165
#
#                gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# United States    19530.365570    21806.035940    24072.632130    25009.559140
# Uruguay           5444.619620     5703.408898     6504.339663     6920.223051
# Venezuela         9541.474188    10505.259660    13143.950950    11152.410110
#
#                gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# United States    29884.350410    32003.932240    35767.433030    39097.099550
# Uruguay           7452.398969     8137.004775     9230.240708     7727.002004
# Venezuela         9883.584648    10733.926310    10165.495180     8605.047831
#
# ...

# %%
processed = americas.tail(n=3) #save 3 rows of americas in processed

# %%
processed # i have to transpose to see only
# Out:
#               continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# United States  Americas    13990.482080    14847.127120    16173.145860
# Uruguay        Americas     5716.766744     6150.772969     5603.357717
# Venezuela      Americas     7689.799761     9802.466526     8422.974165
#
#                gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# United States    19530.365570    21806.035940    24072.632130    25009.559140
# Uruguay           5444.619620     5703.408898     6504.339663     6920.223051
# Venezuela         9541.474188    10505.259660    13143.950950    11152.410110
#
#                gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# United States    29884.350410    32003.932240    35767.433030    39097.099550
# Uruguay           7452.398969     8137.004775     9230.240708     7727.002004
# Venezuela         9883.584648    10733.926310    10165.495180     8605.047831
#
# ...

# %%
processed.columns.format # to see
# Out:
# <bound method Index.format of Index(['continent', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007'],
#       dtype='object')>

# %%
americas.describe() #give statistics of the dataframe = dataframe
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
americas.T.tail(n=3).T #transpose, give the last three rows and transpose again
# Out:
# country        Argentina  Bolivia   Brazil   Canada    Chile Colombia  \
# gdpPercap_1997   10967.3  3326.14  7957.98  28954.9  10118.1  6117.36
# gdpPercap_2002   8797.64  3413.26  8131.21    33329  10778.8  5755.26
# gdpPercap_2007   12779.4  3822.14   9065.8  36319.2  13171.6  7006.58
#
# country        Costa Rica     Cuba Dominican Republic  Ecuador    ...     \
# gdpPercap_1997    6677.05  5431.99             3614.1  7429.46    ...
# gdpPercap_2002    7723.45  6340.65            4563.81  5773.04    ...
# gdpPercap_2007    9645.06   8948.1            6025.37  6873.26    ...
#
# country          Mexico Nicaragua   Panama Paraguay     Peru Puerto Rico  \
# gdpPercap_1997   9767.3   2253.02  7113.69   4247.4  5838.35     16999.4
# gdpPercap_2002  10742.4   2474.55  7356.03  3783.67  5909.02     18855.6
# gdpPercap_2007  11977.6   2749.32  9809.19  4172.84  7408.91     19328.7
#
# country        Trinidad and Tobago United States  Uruguay Venezuela
# ...

# %%
processed = americas.T.tail(n=3).T

# %%
processed
# Out:
#                     gdpPercap_1997 gdpPercap_2002 gdpPercap_2007
# country
# Argentina                  10967.3        8797.64        12779.4
# Bolivia                    3326.14        3413.26        3822.14
# Brazil                     7957.98        8131.21         9065.8
# Canada                     28954.9          33329        36319.2
# Chile                      10118.1        10778.8        13171.6
# Colombia                   6117.36        5755.26        7006.58
# Costa Rica                 6677.05        7723.45        9645.06
# Cuba                       5431.99        6340.65         8948.1
# Dominican Republic          3614.1        4563.81        6025.37
# Ecuador                    7429.46        5773.04        6873.26
# El Salvador                5154.83        5351.57        5728.35
# Guatemala                  4684.31        4858.35        5186.05
# Haiti                      1341.73        1270.36        1201.64
# ...

# %%
processed.columns.format #five format of columns in processed file
# Out:
# <bound method Index.format of Index(['gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'], dtype='object')>

# %%
europe.iloc #subset a part of the dataframe using index
europe.loc # to subset a part of the dataframe by name
favoritecountry = europe.loc['Belgium']

# %%
favoritecountry
# Out:
# gdpPercap_1952     8343.105127
# gdpPercap_1957     9714.960623
# gdpPercap_1962    10991.206760
# gdpPercap_1967    13149.041190
# gdpPercap_1972    16672.143560
# gdpPercap_1977    19117.974480
# gdpPercap_1982    20979.845890
# gdpPercap_1987    22525.563080
# gdpPercap_1992    25575.570690
# gdpPercap_1997    27561.196630
# gdpPercap_2002    30485.883750
# gdpPercap_2007    33692.605080
# Name: Belgium, dtype: float64

# %%
Exercisecountry = europe.loc['Greece']

# %%
Exercisecountry.gdpPercap_2007
# Out:
# 27538.41188

# %%
Exercisecountry1=europe.loc['Iceland']

# %%
Exercisecountry1.gdpPercap_1952
# Out:
# 7267.688428

# %%
ExoDF = pandas.DataFrame (Exercisecountry)

# %%
ExoDF
# Out:
#                       Greece
# gdpPercap_1952   3530.690067
# gdpPercap_1957   4916.299889
# gdpPercap_1962   6017.190733
# gdpPercap_1967   8513.097016
# gdpPercap_1972  12724.829570
# gdpPercap_1977  14195.524280
# gdpPercap_1982  15268.420890
# gdpPercap_1987  16120.528390
# gdpPercap_1992  17541.496340
# gdpPercap_1997  18747.698140
# gdpPercap_2002  22514.254800
# gdpPercap_2007  27538.411880

# %%
europe.loc[['Iceland','Greece'],['gdpPercap_1952','gdpPercap_2007']] #dataframe
# Out:
#          gdpPercap_1952  gdpPercap_2007
# country
# Iceland     7267.688428     36180.78919
# Greece      3530.690067     27538.41188

# %%
processed.to_excel('../results/processed.xlsx') #to save in excel in directory results

# %%
import matplotlib
anz.plot()

# %%
anz.plot()
